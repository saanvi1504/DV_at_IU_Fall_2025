# %% [markdown]
# <a href="https://colab.research.google.com/github/saanvi1504/DV_at_IU_Fall_2025/blob/main/Lesson1_Starter_MPL_Housing_Updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lesson 1 (Matplotlib-First) — Story-Driven Data Visualization with Pandas + Matplotlib

# %% [markdown]
# ## 0) Google Colab Walkthrough

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TODO: Imports (pandas, numpy, matplotlib.pyplot)
# TODO: Read CSV into df (parse_dates=['DateListed'])
# TODO: df.shape, df.head()
import pandas as pd, numpy as np, matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/housing_prices_clean_matplotlib.csv', parse_dates=['DateListed'])
print(df.shape)
df.head()
# Out:
# (900, 10)
#    ListingID DateListed Neighborhood  SquareFeet  Bedrooms  Bathrooms  \
# 0      20100 2024-01-02      Midtown         792         2        2.2
# 1      20657 2024-01-04      Midtown        1985         5        3.2
# 2      20031 2024-01-05    Hillcrest        1054         4        1.0
# 3      20497 2024-01-06    Riverside        2124         5        1.5
# 4      20336 2024-01-06     Lakeside        1274         4        2.4
#
#    HouseAge  DistanceToDowntown  HasGarage   Price
# 0        33                10.0          1  305400
# 1         6                 1.6          1  702000
# 2        16                 5.8          1  424100
# 3        19                12.4          1  658600
# 4        24                 6.7          1  539100

# %% [markdown]
# ## 1) Quick pandas analysis

# %%
# TODO: pandas analysis commands one by one
df.info()
df.describe()
df['Neighborhood'].value_counts.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ListingID           900 non-null    int64
#  1   DateListed          900 non-null    datetime64[ns]
#  2   Neighborhood        900 non-null    object
#  3   SquareFeet          900 non-null    int64
#  4   Bedrooms            900 non-null    int64
#  5   Bathrooms           900 non-null    float64
#  6   HouseAge            900 non-null    int64
#  7   DistanceToDowntown  900 non-null    float64
#  8   HasGarage           900 non-null    int64
#  9   Price               900 non-null    int64
# dtypes: datetime64[ns](1), float64(2), int64(6), object(1)
# memory usage: 70.4+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %% [markdown]
# ## 2) Histogram — Price (Matplotlib attributes)
# - Use: plt.figure(figsize=(8,5)); plt.hist(..., bins=30, alpha=0.8)
# - Add: title, xlabel, ylabel, grid
# - Try: change bins & alpha

# %%
# TODO: Histogram code here
plt.figure(figsize=(8,5))
plt.hist(df['Price'],bins=10, alpha = 1)
plt.title("Listing Prices")
plt.grid(True)
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## 3) Scatter — SquareFeet vs Price (Styling)
# - Attributes: alpha, marker, s, edgecolors
# - Add: title, labels, grid

# %%
# TODO: Scatter code here

# %% [markdown]
# ## 4) Boxplot — Price by Neighborhood
# - df.boxplot(column='Price', by='Neighborhood', rot=35)
# - suptitle(''), grid on y-axis

# %%
# TODO: Boxplot code here
plt.figure(figsize=(20,10))
df.boxplot(column='Price', by= 'Neighborhood',rot=35)
plt.title("Price by Neighborhood")
plt.show()

# %% [markdown]
# ## 5) Time Plot — Daily Avg & 14-day MA

# %%
# TODO: Time series code here

# %% [markdown]
# ## 6) Linear Regression — np.polyfit
# - a, b = np.polyfit(X, y, 1)

# %%
# TODO: Regression overlay code here
x = df['SquareFeet'].values;
y = df['Price'].values
a, b = np.polyfit(x,y,1)
plt.figure(figsize=(20,10))
plt.scatter(x,y,alpha= 0.3)
xs = np.linspace(x.min(), x.max(),200)
ys = a*xs + b
plt.plot(xs, ys, linewidth= 2.5, linestyle='--')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Functions Examples (no input, return output)

# %%
# TODO: Write a function that returns a welcome message

# %%
# TODO: Write a function that returns a list of three libraries you know

# %%
# TODO: Write a function that returns your favorite number

# %% [markdown]
# ### For Loop Examples

# %%
# TODO: Write a loop to print the first 5 unique neighborhoods

# %%
# TODO: Write a loop to print numbers 1 through 5

# %%
# TODO: Write a loop to print column names like 'Price', 'SquareFeet', 'Neighborhood'
